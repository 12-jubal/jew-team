# %% [markdown]
# # Data Preprocessing - cleaning process

# %% [markdown]
# ### - Let’s look at the steps of data pre-processing

# %% [markdown]
# #### 1 - Removing duplicates - Enlever les lignes doubles

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("churn_data.csv")
data
# Out:
#         user  churn   age housing  credit_score  deposits  withdrawal  \
# 0      55409      0  37.0      na           NaN         0           0
# 1      23547      0  28.0       R         486.0         0           0
# 2      58313      0  35.0       R         561.0        47           2
# 3       8095      0  26.0       R         567.0        26           3
# 4      61353      1  27.0      na           NaN         0           0
# ...      ...    ...   ...     ...           ...       ...         ...
# 26995  24291      1  24.0       R         580.0         0           0
# 26996   4116      1  26.0      na           NaN         0           0
# 26997  23740      0  22.0      na           NaN         0           0
# 26998  47663      1  46.0      na         529.0         2           0
# 26999  52752      1  34.0      na         525.0         0           0
#
#        purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# ...

# %%
#trouver les lignes dupliquées(ATTENTION - on obtient des booléens)
duplicates = data.duplicated()
duplicates
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26995    False
# 26996    False
# 26997    False
# 26998    False
# 26999    False
# Length: 27000, dtype: bool

# %%
#Compte des lignes dupliquées et non dupliquées
duplicates.value_counts()
# Out:
# False    26542
# True       458
# dtype: int64

# %%
#Enlever les lignes dupliquées - par rapport à la colonne -"user"-en gardant la 1e ligne
dropped_duplicates = data.drop_duplicates(subset = ["user"],keep="first")
dropped_duplicates
# Out:
#         user  churn   age housing  credit_score  deposits  withdrawal  \
# 0      55409      0  37.0      na           NaN         0           0
# 1      23547      0  28.0       R         486.0         0           0
# 2      58313      0  35.0       R         561.0        47           2
# 3       8095      0  26.0       R         567.0        26           3
# 4      61353      1  27.0      na           NaN         0           0
# ...      ...    ...   ...     ...           ...       ...         ...
# 26995  24291      1  24.0       R         580.0         0           0
# 26996   4116      1  26.0      na           NaN         0           0
# 26997  23740      0  22.0      na           NaN         0           0
# 26998  47663      1  46.0      na         529.0         2           0
# 26999  52752      1  34.0      na         525.0         0           0
#
#        purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# ...

# %% [markdown]
# #### 2 - Fix structural errors - Correction des erreurs de structure

# %%
data.zodiac_sign.value_counts()
# Out:
# Cancer         2424
# Virgo          2410
# Leo            2374
# Taurus         2236
# Gemini         2168
# na             2159
# Libra          2128
# Pisces         2127
# Scorpio        2118
# Aquarius       2117
# Sagittarius    2056
# Aries          2001
# Capricorn       682
# Name: zodiac_sign, dtype: int64

# %%
#création artificielle d erreur structurelle sur libra
data.zodiac_sign = data.zodiac_sign.replace(["na"],"libra")

# %%
#Ici on a libra et Libra qui veulent dire la meme chose, il faut donc les regrouper en une colonne
data.zodiac_sign.value_counts()
# Out:
# Cancer         2424
# Virgo          2410
# Leo            2374
# Taurus         2236
# Gemini         2168
# libra          2159
# Libra          2128
# Pisces         2127
# Scorpio        2118
# Aquarius       2117
# Sagittarius    2056
# Aries          2001
# Capricorn       682
# Name: zodiac_sign, dtype: int64

# %%
#remplacement de libra par Libra(arrangement erreur structurelle)
data.zodiac_sign = data.zodiac_sign.replace(["libra"],"Libra")

# %%
data.zodiac_sign.value_counts()
# Out:
# Libra          4287
# Cancer         2424
# Virgo          2410
# Leo            2374
# Taurus         2236
# Gemini         2168
# Pisces         2127
# Scorpio        2118
# Aquarius       2117
# Sagittarius    2056
# Aries          2001
# Capricorn       682
# Name: zodiac_sign, dtype: int64

# %% [markdown]
# #### 3 - Detecting Outliers - Detection des valeurs érronées

# %%
churn = pd.read_csv("Churn_Modelling.csv")
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#1- premiere methode avec describe
churn.Age.describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
#detection des lignes ayant 92 en age
churn[churn.Age == 92]
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  \
# 6443       6444    15764927  Rogova          753    France   Male   92
# 6759       6760    15660878   T'ien          705    France   Male   92
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6443       3  121513.31              1          0               1
# 6759       1  126076.24              2          1               1
#
#       EstimatedSalary  Exited
# 6443        195563.99       0
# 6759         34436.83       0

# %%
#drop des index correspondants aux lignes ayant 92 en age
churn.drop(labels = [6443,6759],axis=0,inplace=True)

# %%
churn[churn.Age == 92]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
#Schema d un box plot 
fig=plt.figure(figsize = (10,7))
plt.boxplot(churn.Age)
plt.show()

# %% [markdown]
# A z-score determines the position of a data point in terms of its distance from the mean when measured in standard deviation units. In simple explanations how many standard deviation, your point is deviating from the mean.

# %%
#calcul du z_score
from scipy import stats
import numpy as np
z=np.abs(stats.zscore(churn.Age))
print(z)
# Out:
# 0       0.295258
# 1       0.199669
# 2       0.295258
# 3       0.008490
# 4       0.390847
#           ...
# 9995    0.008490
# 9996    0.373867
# 9997    0.278278
# 9998    0.295258
# 9999    1.042992
# Name: Age, Length: 9998, dtype: float64

# %% [markdown]
# The standard normal curve (Z-score) for a set of values represents 99.7% of the data points within the range of –3 and +3 scores, so in practice often the threshold is set to be 3 and anything beyond that is deemed an outlier and hence removed from the dataset if problematic or not a legitimate observation.

# %%
#transformation z en dataframe
z_df = pd.DataFrame(z)

# %%
#renommer age en z_score
z_df = z_df.rename({"Age":"z_score"},axis=1)

# %%
z_df
# Out:
#        z_score
# 0     0.295258
# 1     0.199669
# 2     0.295258
# 3     0.008490
# 4     0.390847
# ...        ...
# 9995  0.008490
# 9996  0.373867
# 9997  0.278278
# 9998  0.295258
# 9999  1.042992
#
# [9998 rows x 1 columns]

# %%
#concaténation de churn et z_df pour tri
data= pd.concat([churn,z_df],axis=1)
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.z_score.describe()
# Out:
# count    9998.000000
# mean        0.758095
# std         0.652177
# min         0.008490
# 25%         0.278278
# 50%         0.582026
# 75%         1.042992
# max         4.692365
# Name: z_score, dtype: float64

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# z_score            float64
# dtype: object

# %%
#selection du dataset debarassé des outliers
selected = data[data.z_score <3]
selected
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.drop(data[data.z_score >3].index, inplace=True)

# %% [markdown]
# #### 4 -Type conversion

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# z_score            float64
# dtype: object

# %%
data.Balance = data.Balance.astype("string")

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance             string
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# z_score            float64
# dtype: object

# %% [markdown]
# #### 5 -Handling missing values

# %% [markdown]
# Instead of dropping its better to replace them with :
#
# 1 - Mean: The mean is the average of a data set. It is “sensitive” to outliers.
# 2 - Median: The median is the middle of the set of numbers. It is resistant to outliers
# 3-  Mode: The mode is the most common number in a data set.
# It is better to use median instead of mean because of the property of not deviating drastically because of outliers

# %%
data.head(1)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
#
#    Tenure Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2     0.0              1          1               1        101348.88
#
#    Exited   z_score
# 0       1  0.295258

# %%
data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# z_score            0
# dtype: int64

# %%
workfile = pd.read_csv("churn_data.csv")
workfile
# Out:
#         user  churn   age housing  credit_score  deposits  withdrawal  \
# 0      55409      0  37.0      na           NaN         0           0
# 1      23547      0  28.0       R         486.0         0           0
# 2      58313      0  35.0       R         561.0        47           2
# 3       8095      0  26.0       R         567.0        26           3
# 4      61353      1  27.0      na           NaN         0           0
# ...      ...    ...   ...     ...           ...       ...         ...
# 26995  24291      1  24.0       R         580.0         0           0
# 26996   4116      1  26.0      na           NaN         0           0
# 26997  23740      0  22.0      na           NaN         0           0
# 26998  47663      1  46.0      na         529.0         2           0
# 26999  52752      1  34.0      na         525.0         0           0
#
#        purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# ...

# %%
workfile.isna().sum()
# Out:
# user                          0
# churn                         0
# age                           4
# housing                       0
# credit_score               8031
# deposits                      0
# withdrawal                    0
# purchases_partners            0
# purchases                     0
# cc_taken                      0
# cc_recommended                0
# cc_disliked                   0
# cc_liked                      0
# cc_application_begin          0
# app_downloaded                0
# web_user                      0
# app_web_user                  0
# ios_user                      0
# android_user                  0
# registered_phones             0
# payment_type                  0
# waiting_4_loan                0
# cancelled_loan                0
# received_loan                 0
# rejected_loan                 0
# zodiac_sign                   0
# left_for_two_month_plus       0
# left_for_one_month            0
# rewards_earned             3227
# ...

# %%
workfile.credit_score.fillna(workfile.credit_score.median(),inplace=True)
workfile
# Out:
#         user  churn   age housing  credit_score  deposits  withdrawal  \
# 0      55409      0  37.0      na         542.0         0           0
# 1      23547      0  28.0       R         486.0         0           0
# 2      58313      0  35.0       R         561.0        47           2
# 3       8095      0  26.0       R         567.0        26           3
# 4      61353      1  27.0      na         542.0         0           0
# ...      ...    ...   ...     ...           ...       ...         ...
# 26995  24291      1  24.0       R         580.0         0           0
# 26996   4116      1  26.0      na         542.0         0           0
# 26997  23740      0  22.0      na         542.0         0           0
# 26998  47663      1  46.0      na         529.0         2           0
# 26999  52752      1  34.0      na         525.0         0           0
#
#        purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# ...

# %%
workfile.isna().sum()
# Out:
# user                          0
# churn                         0
# age                           4
# housing                       0
# credit_score                  0
# deposits                      0
# withdrawal                    0
# purchases_partners            0
# purchases                     0
# cc_taken                      0
# cc_recommended                0
# cc_disliked                   0
# cc_liked                      0
# cc_application_begin          0
# app_downloaded                0
# web_user                      0
# app_web_user                  0
# ios_user                      0
# android_user                  0
# registered_phones             0
# payment_type                  0
# waiting_4_loan                0
# cancelled_loan                0
# received_loan                 0
# rejected_loan                 0
# zodiac_sign                   0
# left_for_two_month_plus       0
# left_for_one_month            0
# rewards_earned             3227
# ...

# %%
#remplacer avec mean(peut aussi etre remplacé avec mode, et median)
workfile.credit_score.fillna(workfile.credit_score.mean(),inplace=True)
workfile
# Out:
#         user  churn   age housing  credit_score  deposits  withdrawal  \
# 0      55409      0  37.0      na         542.0         0           0
# 1      23547      0  28.0       R         486.0         0           0
# 2      58313      0  35.0       R         561.0        47           2
# 3       8095      0  26.0       R         567.0        26           3
# 4      61353      1  27.0      na         542.0         0           0
# ...      ...    ...   ...     ...           ...       ...         ...
# 26995  24291      1  24.0       R         580.0         0           0
# 26996   4116      1  26.0      na         542.0         0           0
# 26997  23740      0  22.0      na         542.0         0           0
# 26998  47663      1  46.0      na         529.0         2           0
# 26999  52752      1  34.0      na         525.0         0           0
#
#        purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# ...

# %% [markdown]
# #### 6 - Feature Scaling

# %% [markdown]
# Standardisation et Normalisation

# %% [markdown]
# Normalization
# Standardization
# Normalization fits the data between the range of [0,1] but sometimes [-1,1] too. It is affected by outliers in a dataset and is useful when you do not know about the distribution of dataset.
#
# Standardization on the other hand is not bound to be within a certain range, it’s quite resistant to outliers and useful when the distribution is normal or Gaussian.

# %% [markdown]
# #### 7 - Data Encoding

# %%
Onehot encoder et Label encoder
